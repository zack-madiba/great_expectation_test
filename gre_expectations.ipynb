# %%
import pandas as pd 
import great_expectations as ge

# %%
df = ge.read_csv('/home/ofral/Bureau/pro_4/data2.csv', sep = ";") #NROWS nombre de lignes a afficher
df.replace(";", ",")
df.to_csv("data2.csv")

# %%
df = pd.read_csv("data2.csv")
df
# Out:
#       Unnamed: 0  id_cas   cas_numEtude  id_temoignage  tem_new  tem_chrono  \
# 0              0       2  1937-01-01656             31        0         NaN
# 1              1       3  1951-06-00002             32        0         NaN
# 2              2       3  1951-06-00002             33        0         NaN
# 3              3       4  1951-08-00003             34        0         NaN
# 4              4       5  1952-06-00004             35        0         NaN
# ...          ...     ...            ...            ...      ...         ...
# 5351        5351    4841  1984-03-50656           4163        0         NaN
# 5352        5352    4841  1984-03-50656           4164        0         NaN
# 5353        5353    4842  1984-03-50657           4165        0         NaN
# 5354        5354    4842  1984-03-50657           4166        0         NaN
# 5355        5355    4851  2018-12-50667           9580        0  2018.12.01
#
# ...
